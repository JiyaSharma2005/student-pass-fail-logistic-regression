# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
data = pd.read_csv(r"C:\Users\LENOVO\Downloads\Student_Data.csv")   # replace with your file name

# %%
X = data[['midterm_score', 'attendance_pct', 'study_hours_per_week', 'homework_pct']]
y = data['pass']

# %%
X.isnull().sum()
y.isnull().sum()
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0
)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print("Model Accuracy:", accuracy)
# Out:
# Model Accuracy: 0.95

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[ 9  1]
#  [ 0 10]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95        10
#            1       0.91      1.00      0.95        10
#
#     accuracy                           0.95        20
#    macro avg       0.95      0.95      0.95        20
# weighted avg       0.95      0.95      0.95        20

# %%
new_student = pd.DataFrame({
    'midterm_score': [58],
    'attendance_pct': [75],
    'study_hours_per_week': [12],
    'homework_pct': [70]
})

prediction = model.predict(new_student)

if prediction[0] == 1:
    print("Student is likely to PASS")
else:
    print("Student is likely to FAIL")
# Out:
# Student is likely to PASS

# %%
datasets = {
    "Dataset 1 (Strong students)": pd.DataFrame({
        'midterm_score': [80, 85, 78, 90, 88, 92, 75, 83],
        'attendance_pct': [90, 92, 88, 95, 93, 96, 85, 89],
        'study_hours_per_week': [15, 16, 14, 18, 17, 19, 13, 15],
        'homework_pct': [85, 88, 80, 90, 87, 92, 78, 84],
        'pass': [1,1,1,1,1,1,1,1]
    }),

    "Dataset 2 (Weak students)": pd.DataFrame({
        'midterm_score': [30, 35, 40, 28, 33, 38, 25, 45],
        'attendance_pct': [50, 55, 60, 48, 52, 58, 45, 62],
        'study_hours_per_week': [4, 5, 6, 3, 4, 5, 2, 7],
        'homework_pct': [40, 45, 50, 38, 42, 48, 35, 55],
        'pass': [0,0,0,0,0,0,0,0]
    }),

    "Dataset 3 (Mixed)": pd.DataFrame({
        'midterm_score': [45, 55, 65, 35, 75, 60, 40, 70],
        'attendance_pct': [65, 75, 85, 60, 90, 80, 62, 88],
        'study_hours_per_week': [8, 10, 12, 6, 15, 11, 7, 14],
        'homework_pct': [55, 65, 75, 50, 85, 70, 52, 80],
        'pass': [0,1,1,0,1,1,0,1]
    }),

    "Dataset 4 (Attendance dominant)": pd.DataFrame({
        'midterm_score': [50, 52, 48, 55, 45, 58, 42, 60],
        'attendance_pct': [90, 92, 88, 95, 85, 97, 82, 98],
        'study_hours_per_week': [7, 8, 6, 9, 5, 10, 4, 11],
        'homework_pct': [60, 62, 58, 65, 55, 68, 52, 70],
        'pass': [1,1,1,1,1,1,1,1]
    }),

    "Dataset 5 (Borderline cases)": pd.DataFrame({
        'midterm_score': [48, 50, 52, 49, 51, 47, 53, 46],
        'attendance_pct': [70, 72, 74, 71, 73, 69, 75, 68],
        'study_hours_per_week': [9, 10, 11, 9, 10, 8, 12, 7],
        'homework_pct': [58, 60, 62, 59, 61, 57, 63, 56],
        'pass': [0,1,1,0,1,0,1,0]
    })
}

# %%
for name, data in datasets.items():
    
    print("\n==============================")
    print(name)
    
    # Select features and target
    X = data[['midterm_score', 'attendance_pct', 'study_hours_per_week', 'homework_pct']]
    y = data['pass']
    
    # Skip dataset if only one class is present
    if y.nunique() < 2:
        print("Skipped → Only one class present in target")
        continue
    
    # Train-test split with stratification
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.25, random_state=42, stratify=y
    )
    
    # Create and train model
    model = LogisticRegression(max_iter=1000)
    model.fit(X_train, y_train)
    
    # Predictions
    y_pred = model.predict(X_test)
    
    # Evaluation
    acc = accuracy_score(y_test, y_pred)
    cm = confusion_matrix(y_test, y_pred)
    
    print("Accuracy:", acc)
    print("Confusion Matrix:\n", cm)
# Out:
# ...
# Dataset 1 (Strong students)
# Skipped → Only one class present in target
#
# ...
# Dataset 2 (Weak students)
# Skipped → Only one class present in target
#
# ...
# Dataset 3 (Mixed)
# Accuracy: 1.0
# Confusion Matrix:
#  [[1 0]
#  [0 1]]
#
# ...
# Dataset 4 (Attendance dominant)
# Skipped → Only one class present in target
#
# ...
# Dataset 5 (Borderline cases)
# Accuracy: 1.0
# Confusion Matrix:
#  [[1 0]
#  [0 1]]
